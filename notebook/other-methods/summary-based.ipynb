# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # LDSC

# %%
df_ldsc = pd.read_csv(
    "/data/jerrylee/pjt/BIGFAM.v.2.0/data/other-methods/ldsc.tsv",
    sep='\t'
) 

df_ldsc
# Out:
#    cohort                     pheno      ldsc  lower_ldsc  upper_ldsc
# 0     UKB                   Albumin  0.144611    0.126167    0.163054
# 1     UKB      Alkaline_phosphatase  0.308597    0.177371    0.439823
# 2     UKB          Apolipoprotein_A  0.285172    0.162102    0.408242
# 3     UKB          Apolipoprotein_B  0.091511    0.049002    0.134021
# 4     UKB  Arm_fat-free_mass__left_  0.269922    0.250285    0.289558
# ..    ...                       ...       ...         ...         ...
# 88    UKB  Mean_sphered_cell_volume  0.200086    0.151048    0.249124
# 89    UKB            Sitting_height  0.348691    0.316000    0.381382
# 90    UKB           Standing_height  0.485223    0.442472    0.527973
# 91    UKB       Trunk_fat-free_mass  0.298052    0.275560    0.320545
# 92    UKB      Trunk_predicted_mass  0.296296    0.273894    0.318699
#
# [93 rows x 5 columns]

# %% [markdown]
# # LDpred2

# %%
df_ldpred = pd.read_csv(
    "/data/jerrylee/pjt/BIGFAM.v.2.0/data/other-methods/LDpred2.tsv",
    sep='\t'
) 

df_ldpred
# Out:
#    cohort                      pheno   LDpred2  lower_LDpred2  upper_LDpred2
# 0     UKB   Arm_fat-free_mass__left_  0.182970       0.179550       0.186558
# 1     UKB  Arm_fat-free_mass__right_  0.184147       0.180674       0.187685
# 2     UKB        Arm_fat_mass__left_  0.153206       0.149904       0.156531
# 3     UKB       Arm_fat_mass__right_  0.153098       0.149781       0.156381
# 4     UKB  Arm_fat_percentage__left_  0.147812       0.144527       0.151056
# ..    ...                        ...       ...            ...            ...
# 60    UKB   Mean_sphered_cell_volume  0.133801       0.130410       0.137273
# 61    UKB             Sitting_height  0.241571       0.237649       0.245502
# 62    UKB            Standing_height  0.342097       0.337678       0.346658
# 63    UKB        Trunk_fat-free_mass  0.202157       0.198515       0.205789
# 64    UKB       Trunk_predicted_mass  0.201041       0.197452       0.204668
#
# [65 rows x 5 columns]
