# %%
import pandas as pd
import numpy as np
import os
from multiprocessing import Pool
from tqdm import tqdm

# %%
cohort = "GS"

# %%
df_pair = pd.read_csv(
    f"/data/jerrylee/pjt/BIGFAM.v.2.0/data/{cohort}/relationship_information/relatives.formatted.info",
    sep='\t'
)
df_pair
# Out:
#        DOR rcode                relationship  volid  relid  volage  relage  \
# 0        1    SB             daughter-sister  18826  21244      50      36
# 1        1    SB       different-sex-sibling  34422  23884      33      35
# 2        1    PC             daughter-mother  79198  67531      66      44
# 3        1    SB             daughter-sister  20399  67531      38      44
# 4        1    SB             daughter-sister  67267  67531      43      44
# ...    ...   ...                         ...    ...    ...     ...     ...
# 38001    3   HAV  son-mother-father-daughter  34570  78069      50      39
# 38002    3   HAV  son-mother-father-daughter  97449  79361      40      29
# 38003    3   HAV  son-mother-father-daughter  97449   5360      40      22
# 38004    3   HAV  son-mother-father-daughter  15442  83545      35      29
# 38005    3   HAV  son-mother-father-daughter  49646  29717      58      26
#
#       volsex relsex       Erx
# 0          F      F  0.750000
# 1          F      M  0.353553
# 2          F      F  0.500000
# 3          F      F  0.750000
# 4          F      F  0.750000
# ...      ...    ...       ...
# 38001      F      M  0.353553
# 38002      F      M  0.353553
# 38003      F      M  0.353553
# 38004      F      M  0.353553
# 38005      F      M  0.353553
#
# [38006 rows x 10 columns]

# %%
def get_unique_ids(df):
    return list(set(df["volid"]) | set(df["relid"]))

# %%
def process_phenotype(args):
    pheno_fn, pheno_path, df_pair, get_unique_ids = args
    
    pheno = pheno_fn.split(".")[0]
    df_pheno = pd.read_csv(f"{pheno_path}/{pheno_fn}", sep='\t')
    
    for DOR in [1, 2, 3]:
        target_pairs = df_pair[df_pair["DOR"] == DOR]
        target_ids = get_unique_ids(target_pairs)
        
        tmp = df_pheno[df_pheno["eid"].isin(target_ids)][["eid", "eid", "pheno"]].copy()
        tmp.columns = ["FID", "IID", "trait"]
        
        # save phenotype 
        tmp_fn = f"/data/jerrylee/pjt/BIGFAM.v.2.0/tmp/{pheno}.txt"
        tmp.to_csv(tmp_fn, sep='\t', index=False)
        
        # run RDR
        if cohort == "UKB":
            cmd = "python /data/jerrylee/pjt/BIGFAM.v.0.1/BIGFAM/RELT.py {grm_id} {grm_bin} {pheno_fn} {out_fn}".format(
                grm_id = f"/data/jerrylee/data/{cohort}/grm_rel/DOR{DOR}_chrALL.grm.id",
                grm_bin = f"/data/jerrylee/data/{cohort}/grm_rel/DOR{DOR}_chrALL.grm.bin",
                pheno_fn = tmp_fn,
                out_fn = f"/data/jerrylee/pjt/BIGFAM.v.2.0/data/other-methods/RDR/{pheno}.{DOR}"
            )
        if cohort == "GS":
            cmd = "python /data/jerrylee/pjt/BIGFAM.v.0.1/BIGFAM/RELT.py {grm_id} {grm_bin} {pheno_fn} {out_fn}".format(
                grm_id = f"/data/jerrylee/data/{cohort}/GRM/GS_GWAS.grm.id",
                grm_bin = f"/data/jerrylee/data/{cohort}/GRM/GS_GWAS.grm.bin",
                pheno_fn = tmp_fn,
                out_fn = f"/data/jerrylee/pjt/BIGFAM.v.2.0/data/other-methods/RDR/{cohort}/{pheno}.{DOR}"
            )
        os.system(cmd)
        
        # remove phenotype file
        cmd = f"rm {tmp_fn}"
        os.system(cmd)

# 메인 코드
pheno_path = f"/data/jerrylee/pjt/BIGFAM.v.0.1/data/{cohort}/phenotype"
pheno_fns = os.listdir(pheno_path)

# 프로세스 풀 생성
num_processes = 20  # 원하는 프로세스 수로 조정
pool = Pool(processes=num_processes)

# 각 phenotype 파일에 대한 인자 생성
args = [(pheno_fn, pheno_path, df_pair, get_unique_ids) for pheno_fn in pheno_fns]

# 병렬 처리 실행 (tqdm으로 진행상황 표시)
for _ in tqdm(pool.imap_unordered(process_phenotype, args), total=len(args)):
    pass

# 풀 종료
pool.close()
pool.join()
# Out:
# Computing regression estimate
# -2.3459480334165624e-07
# 0.014311912467275098
# Computing regression estimate
# -2.235911192025749e-07
# 0.014843655539399474
# Computing regression estimate
# -2.388709138267211e-07
# 0.014029225374098536
# v: 0.378
# Phenotypic variance estimate: 1.015
# Estimating heritability
# 468 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.2127136629977334e-05v: 0.598
# Phenotypic variance estimate: 0.992
#
# Estimating heritability
# 0.0702541500156487
# 456 pairs with relatedness >0.05 excluded
# Computing regression estimate
# Computing regression estimate
# 1.2616005963222027e-05
# 0.07259377001161403
# -2.503712948353354e-07
# 0.014650000121768285
# v_g: 0.468
# Estimating standard error
# v_g: 0.092
# Estimating standard error
# v_g: 0.092 (0.407)v_g: 0.468 (0.422)
# Estimating variance of phenotypic variance estimate
#
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.472 (0.4232)
# v_g/v_y: 0.091 (0.4005)
# v: 1.203
# Phenotypic variance estimate: 1.07
# Estimating heritability
# 476 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.1998570750969725e-05
# 0.06932935984097437
# v_g: 1.139
# Estimating standard error
# v: 0.226
# Phenotypic variance estimate: 0.823
# v_g: 1.139 (0.503)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 1.064 (0.4594)
# Estimating heritability
# 458 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.2227882498885551e-05
# 0.07161375390564301
# v_g: 0.577
# Estimating standard error
# v_g: 0.577 (0.327)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.701 (0.3961)
# Computing regression estimate
# IDs of 19982 individuals read for relatedness matrices
#
# Computing regression estimate
# Non-missing phenotypes of 295 individuals included
# 295 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 298 individuals included
# 298 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 300 individuals included
# 300 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Computing regression estimate
# Computing regression estimate
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 295 individuals included
# 295 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Computing regression estimate
# Computing regression estimate
# Computing regression estimate
# Computing regression estimate
# Computing regression estimate
# Computing regression estimate
# Computing regression estimate
# Computing regression estimate
# Computing regression estimate
# Computing regression estimate
# -2.966087741707525e-09
# Computing regression estimate
# Computing regression estimate
# -2.9305866192305704e-09
# -1.5924532639994698e-09
# 0.00025201681682288253
# -1.2852250636067867e-09
# -1.3297949435699776e-09
# -1.3297949435699776e-09
# -1.2826020003865499e-09
# -1.3297949435699776e-09
# 0.00024866097018583254
# -1.3488543346198374e-09
# -1.3297949435699776e-09
# -1.3297949435699776e-09
# 0.00019107535973264498
# -1.3297949435699776e-09
# -1.3297949435699776e-09
# -1.406028372073371e-09
# -1.5064604039898028e-09
# 0.00017647976858144556
# -1.5757220451709947e-09
# 0.00018053290035280009
# 0.00017647985936994156
# 0.00018053290035280009
# 0.00018123067029039345
# v: 0.349
# Phenotypic variance estimate: 0.996
# 0.00018053290035280009
# 0.00018053290035280009
# 0.00018053290035280009
# 0.00018053290035280009
# v: 0.573
# Phenotypic variance estimate: 1.005
# 0.00018998326361192652
# 0.00018053290035280009
# 0.00018536579733006457
# v: 0.527
# Phenotypic variance estimate: 0.955
# 0.00019349886049023306
# v: 0.202
# Phenotypic variance estimate: 0.955
# Estimating heritability
# v: 0.005
# Phenotypic variance estimate: 1.4
# 24768 pairs with relatedness >0.05 excluded
# v: 0.067
# Phenotypic variance estimate: 1.066
# Estimating heritability
# Estimating heritability
# Computing regression estimate
# 25098 pairs with relatedness >0.05 excluded
# v: 0.089
# Phenotypic variance estimate: 1.063
# Computing regression estimate
# 33090 pairs with relatedness >0.05 excluded
# v: 0.265
# Phenotypic variance estimate: 0.963
# v: 0.293
# Phenotypic variance estimate: 0.982
# v: 0.003
# Phenotypic variance estimate: 0.809
# Computing regression estimate
# v: 0.004
# Phenotypic variance estimate: 1.401
# v: 0.042
# Phenotypic variance estimate: 1.192
# v: 0.137
# Phenotypic variance estimate: 0.913
# v: 0.425
# Phenotypic variance estimate: 0.955
# v: 0.276
# Phenotypic variance estimate: 1.023
# v: 0.0
# Phenotypic variance estimate: 0.808
# Estimating heritability
# Estimating heritability
# 1.823928285181668e-07
# Estimating heritability
# Estimating heritability
# 35192 pairs with relatedness >0.05 excluded
# 35192 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 35192 pairs with relatedness >0.05 excluded
# Estimating heritability
# Computing regression estimate
# 36022 pairs with relatedness >0.05 excluded
# 1.8486580953085517e-07
# Computing regression estimate
# Estimating heritability
# Estimating heritability
# Computing regression estimate
# 35104 pairs with relatedness >0.05 excluded
# Estimating heritability
# Estimating heritability
# 0.0011522024698620912
# Computing regression estimate
# 36020 pairs with relatedness >0.05 excluded
# Computing regression estimate
# Estimating heritability
# 35192 pairs with relatedness >0.05 excluded
# 35192 pairs with relatedness >0.05 excluded
# 32690 pairs with relatedness >0.05 excluded
# Computing regression estimate
# Estimating heritability
# Estimating heritability
# Computing regression estimate
# Computing regression estimate
# 0.0011674410243115675
# Estimating heritability
# 1.390743070014322e-07
# 34368 pairs with relatedness >0.05 excluded
# 33318 pairs with relatedness >0.05 excluded
# 35192 pairs with relatedness >0.05 excluded
# Computing regression estimate
# Computing regression estimate
# 35192 pairs with relatedness >0.05 excluded
# Computing regression estimate
# Computing regression estimate
# 1.3082813795479516e-07
# v_g: 0.469
# Estimating standard error
# 1.3082813795479516e-07
# 0.0008720627584291767
# 1.276077670705059e-07
# 1.3082813795479516e-07
# v_g: 0.23
# Estimating standard error
# 1.2761887790808624e-07
# 1.308857335377095e-07
# 1.3082813795479516e-07
# 0.0008194797107421915
# 0.0008194797107421915
# 1.40989935391613e-07
# 1.345457235714279e-07
# 0.0007999430543096641
# 1.3082813795479516e-07
# 0.0008194797107421915
# 1.3812742370441065e-07
# 1.3082813795479516e-07
# 0.000799944881111043
# 0.0008210468513650252
# 1.3082813795479516e-07
# v_g: 0.363
# Estimating standard error
# 0.0008829814467808879
# 0.0008418731938031228
# 0.0008194797107421915
# 0.0008194797107421915
# 0.0008194797107421915
# v_g: 0.05
# Estimating standard error
# v_g: 0.039
# Estimating standard error
# v_g: 0.079
# Estimating standard error
# v_g: 0.027
# Estimating standard error
# 0.0008653924405040124
# 0.0008194797107421915
# v_g: 0.06
# Estimating standard error
# v_g: 0.226
# Estimating standard error
# v_g: 0.043
# Estimating standard error
# v_g: 0.084
# Estimating standard error
# v_g: 0.001
# Estimating standard error
# v_g: 0.007
# Estimating standard error
# v_g: 0.036
# Estimating standard error
# v_g: 0.15
# Estimating standard error
# v_g: 0.469 (0.097)
# Estimating variance of phenotypic variance estimate
# v_g: 0.008
# Estimating standard error
# v_g: 0.23 (0.076)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.466 (0.0948)
# v_g/v_y: 0.231 (0.0753)
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2228 individuals included
# 2228 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2213 individuals included
# 2213 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v_g: 0.363 (0.085)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g: 0.06 (0.063)
# Estimating variance of phenotypic variance estimate
# v_g: 0.027 (0.047)
# Estimating variance of phenotypic variance estimate
# v_g: 0.079 (0.053)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g: 0.05 (0.049)
# Estimating variance of phenotypic variance estimate
# v_g: 0.039 (0.057)
# Estimating variance of phenotypic variance estimate
# v_g: 0.043 (0.048)
# Estimating variance of phenotypic variance estimate
# v_g/v_y: 0.381 (0.0875)
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g: 0.226 (0.062)
# Estimating variance of phenotypic variance estimate
# v_g/v_y: 0.058 (0.0615)
# Estimating covariance between genetic variance and phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.026 (0.0444)
# v_g/v_y: 0.083 (0.0552)
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g: 0.007 (0.033)
# Estimating variance of phenotypic variance estimate
# v_g: 0.084 (0.059)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g: 0.008 (0.051)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.048 (0.0523)
# v_g: 0.036 (0.057)
# Estimating variance of phenotypic variance estimate
# v_g/v_y: 0.047 (0.0458)
# v_g: 0.001 (0.033)
# Estimating variance of phenotypic variance estimate
# v_g: 0.15 (0.075)
# Estimating variance of phenotypic variance estimate
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2639 individuals included
# 2639 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v_g/v_y: 0.028 (0.0407)
# Estimating covariance between genetic variance and phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# IDs of 19982 individuals read for relatedness matrices
#
# v_g/v_y: 0.231 (0.0625)
# Non-missing phenotypes of 2534 individuals included
# Estimating covariance between genetic variance and phenotypic variance estimate
# 2534 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Estimating covariance between genetic variance and phenotypic variance estimate
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2651 individuals included
# 2651 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v_g/v_y: 0.087 (0.0614)
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.009 (0.0407)
# v_g/v_y: 0.007 (0.0426)
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.026 (0.0407)
# IDs of 19982 individuals read for relatedness matrices
#
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2678 individuals included
# 2678 individuals with both relatedness and trait information
# Non-missing phenotypes of 2517 individuals included
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# 2517 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v_g/v_y: 0.001 (0.0405)
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2651 individuals included
# 2651 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v_g/v_y: 0.157 (0.0778)
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2651 individuals included
# 2651 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2678 individuals included
# 2678 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2656 individuals included
# 2656 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2651 individuals included
# 2651 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2651 individuals included
# 2651 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2651 individuals included
# 2651 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2546 individuals included
# 2546 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2651 individuals included
# 2651 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Computing regression estimate
# -1.178095583420181e-05
# 0.09553474584838952
# v: 0.6
# Phenotypic variance estimate: 1.04
# Estimating heritability
# 118 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 0.00011356399623107525
# 0.6231486425075423
# v_g: 0.982
# Estimating standard error
# v_g: 0.982 (1.209)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.945 (1.1593)
# Computing regression estimate
# -1.1173701552432282e-05
# 0.09468118109606487
# v: 1.24
# Phenotypic variance estimate: 1.194
# Estimating heritability
# 120 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 0.00010869329173833835
# 0.602137440859802
# v_g: 1.437
# Estimating standard error
# v_g: 1.437 (1.424)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 1.203 (1.1817)
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 17527 individuals included
# 17527 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 16943 individuals included
# 16943 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Computing regression estimate
# -1.1499694105003498e-05
# 0.09514888917352382
# v: 0.28
# Phenotypic variance estimate: 0.964
# Estimating heritability
# 118 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 0.00010900159691934361
# 0.60949075164665
# v_g: 1.177
# Estimating standard error
# v_g: 1.177 (1.085)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 1.221 (1.1256)
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 16728 individuals included
# 16728 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Computing regression estimate
# -1.2001743697714545e-05
# 0.09681465994022952
# v: -0.19
# Phenotypic variance estimate: 0.868
# Estimating heritability
# 116 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 0.0001091585213828459
# 0.6216987635049253
# v_g: -1.076
# Estimating standard error
# v_g: -1.076 (0.957)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: -1.24 (1.1034)
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 17093 individuals included
# 17093 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Computing regression estimate
# -1.9024788690576503e-07
# 0.0016696473332852239
# v: 0.334
# Phenotypic variance estimate: 1.062
# Estimating heritability
# 5996 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.933923860804592e-06
# 0.011097239419088734
# v_g: 0.045
# Estimating standard error
# v_g: 0.045 (0.186)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.042 (0.1752)
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 1878 individuals included
# 1878 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Computing regression estimate
# -1.3604453904556865e-07
# 0.0011712273737717442
# Computing regression estimate
# -1.5257511729718278e-07
# 0.0012347711684330609
# v: 0.328
# Phenotypic variance estimate: 0.779
# Estimating heritability
# 8696 pairs with relatedness >0.05 excluded
# Computing regression estimate
# v: 0.529
# Phenotypic variance estimate: 0.801
# 1.3668141735350881e-06
# 0.007796246465215793
# Estimating heritability
# 8116 pairs with relatedness >0.05 excluded
# Computing regression estimate
# Computing regression estimate
# v_g: 0.176
# Estimating standard error
# 1.4742831385407175e-06
# Computing regression estimate
# 0.008445313729464174
# -1.879225416724562e-07
# v_g: 0.176 (0.126)
# Estimating variance of phenotypic variance estimate
# 0.0016532540494694455
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.225 (0.1611)
# -1.3265129008372493e-07
# v_g: 0.375
# Estimating standard error
# 0.001140537629262275
# v_g: 0.375 (0.156)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v: 0.633
# Phenotypic variance estimate: 1.098
# v_g/v_y: 0.468 (0.1916)
# Estimating heritability
# 6078 pairs with relatedness >0.05 excluded
# Computing regression estimate
# v: 0.356
# Phenotypic variance estimate: 0.687
# 1.9054929835926224e-06
# 0.010955197321638275
# v_g: 0.644
# Estimating standard error
# v_g: 0.644 (0.221)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.587 (0.1981)
# Estimating heritability
# 8956 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.3202626682409199e-06
# 0.007567394057138283
# Computing regression estimate
# Computing regression estimate
# v_g: 0.315
# Estimating standard error
# -1.3694142525342055e-07
# v_g: 0.315 (0.117)
# Estimating variance of phenotypic variance estimate
# 0.0011519630469521186
# -1.3694142525342055e-07
# Estimating covariance between genetic variance and phenotypic variance estimate
# IDs of 19982 individuals read for relatedness matrices
#
# v_g/v_y: 0.458 (0.1685)
# 0.0011519630469521186
# Non-missing phenotypes of 17375 individuals included
# 17375 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v: 0.019
# Phenotypic variance estimate: 1.565
# IDs of 19982 individuals read for relatedness matrices
#
# v: 0.003
# Phenotypic variance estimate: 0.006
# Non-missing phenotypes of 1898 individuals included
# 1898 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Computing regression estimate
# Estimating heritability
# 8818 pairs with relatedness >0.05 excluded
# Computing regression estimate
# -1.5396944968926997e-07
# 1.3481653851703974e-06
# Computing regression estimate
# Computing regression estimate
# 0.0012587087935216866
# 0.007722609697026021
# Estimating heritability
# 8818 pairs with relatedness >0.05 excluded
# Computing regression estimate
# Computing regression estimate
# -1.4965725197399976e-07
# 1.3481653851703974e-06
# -1.3694142525342055e-07
# 0.0012298259896046544
# v_g: 0.157
# Estimating standard error
# 0.007722609697026021
# -1.3694142525342055e-07
# 0.0011519630469521186
# 0.0011519630469521186
# v: 0.088
# Phenotypic variance estimate: 0.482
# v_g: 0.157 (0.196)
# Estimating variance of phenotypic variance estimate
# IDs of 19982 individuals read for relatedness matrices
#
# v_g: 0.002
# Estimating standard error
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.101 (0.1252)v: 0.396
#
# Phenotypic variance estimate: 0.614
# Non-missing phenotypes of 14812 individuals included
# v: 0.086
# Phenotypic variance estimate: 0.922
# 14812 individuals with both relatedness and trait information
# Estimating heritability
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# 8004 pairs with relatedness >0.05 excluded
# Computing regression estimate
# v: 0.016
# Phenotypic variance estimate: 1.563
# 1.495038473800353e-06
# v_g: 0.002 (0.001)
# Estimating variance of phenotypic variance estimate
# 0.008556093843543503
# Estimating covariance between genetic variance and phenotypic variance estimate
# Estimating heritability
# v_g/v_y: 0.333 (0.1645)
# Estimating heritability
# 8176 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 8818 pairs with relatedness >0.05 excluded
# Computing regression estimate
# Estimating heritability
# v_g: 0.036
# Estimating standard error
# 8818 pairs with relatedness >0.05 excluded
# 1.3481653851703974e-06
# Computing regression estimate
# 1.4646681172351448e-06
# 0.007722609697026021
# 0.008365395507765794
# v_g: 0.036 (0.07)
# Estimating variance of phenotypic variance estimate
# 1.3481653851703974e-06
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.074 (0.1453)
# 0.007722609697026021
# v_g: 0.036
# Estimating standard error
# IDs of 19982 individuals read for relatedness matrices
#
# v_g: 0.1
# Estimating standard error
# v_g: 0.036 (0.121)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.039 (0.1313)
# Computing regression estimate
# Non-missing phenotypes of 17375 individuals included
# 17375 individuals with both relatedness and trait information
# v_g: 0.143
# Estimating standard error
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v_g: 0.1 (0.118)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.163 (0.1908)
# v_g: 0.143 (0.195)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.091 (0.125)
# -1.3694142525342055e-07
# 0.0011519630469521186
# Computing regression estimate
# -1.3694142525342055e-07
# Computing regression estimate
# 0.0011519630469521186
# v: 0.0
# Phenotypic variance estimate: 0.001
# -1.3265129008372493e-07
# 0.001140537629262275
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 1877 individuals included
# 1877 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Estimating heritability
# 8818 pairs with relatedness >0.05 excluded
# v: -0.007
# Phenotypic variance estimate: 1.145
# Computing regression estimate
# 1.3481653851703974e-06
# 0.007722609697026021
# v: 0.432
# Phenotypic variance estimate: 0.999
# IDs of 19982 individuals read for relatedness matrices
#
# Estimating heritability
# 8818 pairs with relatedness >0.05 excluded
# Computing regression estimate
# v_g: -0.0
# Estimating standard error
# Non-missing phenotypes of 16968 individuals included
# Estimating heritability
# 8956 pairs with relatedness >0.05 excluded
# 16968 individuals with both relatedness and trait information
# 1.3481653851703974e-06
# Computing regression estimate
# IDs of 19982 individuals read for relatedness matrices
#
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v_g: -0.0 (0.0)
# Estimating variance of phenotypic variance estimate
# 0.007722609697026021
# Estimating covariance between genetic variance and phenotypic variance estimate
# Non-missing phenotypes of 14810 individuals included
# v_g/v_y: -0.002 (0.1427)
# 14810 individuals with both relatedness and trait information
# 1.3202626682409199e-06
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# 0.007567394057138283
# v_g: 0.049
# Estimating standard error
# IDs of 19982 individuals read for relatedness matrices
#
# v_g: 0.183
# Estimating standard error
# IDs of 19982 individuals read for relatedness matrices
#
# v_g: 0.049 (0.142)
# Estimating variance of phenotypic variance estimate
# Non-missing phenotypes of 16967 individuals included
# Estimating covariance between genetic variance and phenotypic variance estimate
# IDs of 19982 individuals read for relatedness matrices
#
# v_g/v_y: 0.043 (0.1238)
# 16967 individuals with both relatedness and trait information
# Non-missing phenotypes of 17563 individuals included
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v_g: 0.183 (0.161)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.183 (0.1607)
# 17563 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Non-missing phenotypes of 17375 individuals included
# 17375 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 17375 individuals included
# Computing regression estimate
# 17375 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# -1.3446304933792255e-07
# IDs of 19982 individuals read for relatedness matrices
#
# 0.0011614515082127973
# Non-missing phenotypes of 17578 individuals included
# 17578 individuals with both relatedness and trait information
# IDs of 19982 individuals read for relatedness matrices
#
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Non-missing phenotypes of 17375 individuals included
# 17375 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v: 0.354
# Phenotypic variance estimate: 0.715
# Estimating heritability
# 8786 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.3419495848929797e-06
# 0.007693118797578597
# v_g: 0.221
# Estimating standard error
# v_g: 0.221 (0.121)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.309 (0.1676)
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 1879 individuals included
# 1879 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Computing regression estimate
# -1.3694142525342055e-07
# 0.0011519630469521186
# v: -0.006
# Phenotypic variance estimate: 0.894
# Estimating heritability
# 8818 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.3481653851703974e-06
# 0.007722609697026021
# v_g: 0.02
# Estimating standard error
# v_g: 0.02 (0.111)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.022 (0.1238)
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 16957 individuals included
# 16957 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Computing regression estimate
# Computing regression estimate
# Computing regression estimate
# 3.0692147906877478e-09
# Computing regression estimate
# 3.269807639181733e-09
# Computing regression estimate
# 2.541858000115054e-07
# 0.005437816485274073
# v: 0.336
# Phenotypic variance estimate: 0.985
# Estimating heritability
# 778 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.9051921526495272e-06
# 0.015324133190576189
# v_g: 0.354
# Estimating standard error
# v_g: 0.354 (0.192)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.36 (0.1942)
# 3.3559089558721754e-09
# 6.296122060253367e-05
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 871 individuals included
# 871 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# 6.723603778489475e-05
# 6.900491675459658e-05
# Computing regression estimate
# 2.4945672957399855e-07
# 0.005317206187298966
# v: 0.498
# Phenotypic variance estimate: 0.988
# Estimating heritability
# 792 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.8692828328536494e-06
# 0.015002249891938556
# v_g: 0.356
# Estimating standard error
# v_g: 0.356 (0.202)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.361 (0.2033)
# 3.207021755426791e-09
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 877 individuals included
# 877 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v: 0.791
# Phenotypic variance estimate: 0.992
# 6.597720440279975e-05
# v: 0.26
# Phenotypic variance estimate: 1.001
# Computing regression estimate
# v: 0.137
# Phenotypic variance estimate: 0.999
# Computing regression estimate
# Computing regression estimate
# Computing regression estimate
# Computing regression estimate
# 2.524611712991499e-07
# 0.005439697872930871
# v: 0.35
# Phenotypic variance estimate: 1.037
# Estimating heritability
# 778 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.9031987921340543e-06
# 0.015339020937640703
# v_g: 0.123
# Estimating standard error
# v_g: 0.123 (0.202)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.119 (0.1946)
# Computing regression estimate
# 2.506358539464619e-07
# 0.005431423142015462
# Computing regression estimate
# v: 0.424
# Phenotypic variance estimate: 0.992
# Computing regression estimate
# Estimating heritability
# 780 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.8952757504608007e-06
# 0.01530900439831387
# v_g: 0.289
# Estimating standard error
# v_g: 0.289 (0.199)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.291 (0.1999)
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 871 individuals included
# 871 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Computing regression estimate
# Estimating heritability
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 872 individuals included
# 872 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Computing regression estimate
# 62738 pairs with relatedness >0.05 excluded
# Estimating heritability
# Computing regression estimate
# Computing regression estimate
# v: 0.147
# Phenotypic variance estimate: 1.013
# Computing regression estimate
# Estimating heritability
# 58700 pairs with relatedness >0.05 excluded
# 57218 pairs with relatedness >0.05 excluded
# 4.129812263468496e-09
# Computing regression estimate
# Computing regression estimate
# 4.128878337309155e-09
# 3.2645847600927973e-09
# 3.1228881326380083e-09
# 3.1228881326380083e-09
# 8.709570017219489e-05
# Estimating heritability
# 3.0580678910733176e-09
# 8.70757489686062e-05
# 3.1228881326380083e-09
# 60046 pairs with relatedness >0.05 excluded
# 3.05191274937583e-09
# Computing regression estimate
# 2.1876499633733227e-08
# 6.707920507264312e-05
# 6.405116432644027e-05
# 3.266053954919857e-09
# 6.405116432644027e-05
# 3.1228881326380083e-09
# 2.404037495850083e-08
# 2.3432715006701633e-08
# 6.272101604706745e-05
# Computing regression estimate
# v: 0.151
# Phenotypic variance estimate: 1.002
# 6.405116432644027e-05
# 6.259508900200828e-05
# 0.00017686996351349188
# v: 0.442
# Phenotypic variance estimate: 0.994
# 6.711107735295034e-05
# 0.00019428044782210242
# 6.405116432644027e-05
# 0.00018935520808365994
# v: 0.187
# Phenotypic variance estimate: 1.014
# Computing regression estimate
# v: 0.108
# Phenotypic variance estimate: 1.026
# 2.3054423136440006e-08
# Estimating heritability
# Estimating heritability
# v: 0.292
# Phenotypic variance estimate: 1.001
# 44632 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 44622 pairs with relatedness >0.05 excluded
# Computing regression estimate
# v: 0.201
# Phenotypic variance estimate: 1.0
# Computing regression estimate
# -2.3278092729060006e-07
# 0.014629745638701895
# v_g: 0.604
# Estimating standard error
# v: 0.369
# Phenotypic variance estimate: 1.076
# Estimating heritability
# 460 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.2220271224730504e-05
# 0.07129733536987914
# v_g: 0.355
# Estimating standard error
# v_g: 0.355 (0.432)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.33 (0.4003)
# v: -0.003
# Phenotypic variance estimate: 0.764
# 0.0001859680202642347
# 3.1228881326380083e-09
# v_g: 0.015
# Estimating standard error
# v: 0.245
# Phenotypic variance estimate: 1.006
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 296 individuals included
# 296 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v: 0.039
# Phenotypic variance estimate: 1.043
# Estimating heritability
# v: 0.403
# Phenotypic variance estimate: 1.028
# v_g: 0.185
# Estimating standard error
# 58838 pairs with relatedness >0.05 excluded
# Computing regression estimate
# Estimating heritability
# Estimating heritability
# 3.054951614683041e-08
# 6.405116432644027e-05
# 3.2695677438651443e-09
# Estimating heritability
# Estimating heritability
# Computing regression estimate
# -2.3459480334165624e-07
# 0.014311912467275098
# v: 0.736
# Phenotypic variance estimate: 1.084
# Estimating heritability
# 468 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.2127136629977334e-05
# 0.0702541500156487
# v_g: 0.445
# Estimating standard error
# v_g: 0.445 (0.463)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.41 (0.4243)
# 61714 pairs with relatedness >0.05 excluded
# 61714 pairs with relatedness >0.05 excluded
# 61714 pairs with relatedness >0.05 excluded
# Computing regression estimate
# Computing regression estimate
# 63052 pairs with relatedness >0.05 excludedComputing regression estimate
#
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 298 individuals included
# 298 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# 0.00024773052231647695
# Computing regression estimate
# Estimating heritability
# 3.055835791332535e-08
# Estimating heritability
# 58804 pairs with relatedness >0.05 excluded
# Computing regression estimate
# v_g: 0.064
# Estimating standard error
# 6.717295910208826e-05
# Estimating heritability
# 63170 pairs with relatedness >0.05 excluded
# 0.00024779109133023165
# Computing regression estimate
# 61714 pairs with relatedness >0.05 excluded
# Computing regression estimate
# -2.3278092729060006e-07
# 0.014629745638701895
# Computing regression estimate
# -2.440356267813457e-07
# 0.014590836931434295
# 2.3364213031441425e-08
# v: 0.594
# Phenotypic variance estimate: 1.487
# Estimating heritability
# 460 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.2220271224730504e-05
# 0.07129733536987914
# v_g: 0.435
# Estimating standard error
# v_g: 0.435 (0.603)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.292 (0.4046)
# v: 0.691
# Phenotypic variance estimate: 1.027
# Estimating heritability
# 462 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.2157260157387202e-05
# 0.07114423513776663
# v_g: 0.809
# Estimating standard error
# v_g: 0.809 (0.441)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.787 (0.4244)
# Computing regression estimate
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 296 individuals included
# 296 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v_g: 0.339
# Estimating standard error
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 296 individuals included
# 296 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v: -0.067
# Phenotypic variance estimate: 1.044
# 2.2272492349321086e-08
# v: 0.455
# Phenotypic variance estimate: 0.862
# 0.00018882651182105655
# 2.1790078951218864e-08
# v_g: 0.115
# Estimating standard error
# 2.3356525269824522e-08
# 2.2272492349321086e-08
# 2.2272492349321086e-08
# 2.1758641763548223e-08
# 0.00017999936504039198
# 0.00017616248442421737
# 2.2272492349321086e-08
# Estimating heritability
# 0.00018883087467069746
# 0.00017999936504039198
# 61714 pairs with relatedness >0.05 excluded
# 0.00017999936504039198
# Computing regression estimate
# Estimating heritability
# 0.00017586681845213996
# v_g: 0.107
# Estimating standard error
# 58740 pairs with relatedness >0.05 excluded
# Computing regression estimate
# v_g: -0.008
# Estimating standard error
# 0.00017999936504039198
# v_g: 0.193
# Estimating standard error
# v_g: 0.13
# Estimating standard error
# v_g: 0.054
# Estimating standard error
# v_g: 0.604 (0.084)
# Estimating variance of phenotypic variance estimate
# v_g: 0.187
# Estimating standard error
# v_g: 0.206
# Estimating standard error
# 2.2272492349321086e-08
# 2.3390258108582695e-08
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g: 0.185 (0.038)
# Estimating variance of phenotypic variance estimate
# v_g: 0.015 (0.028)
# Estimating variance of phenotypic variance estimate
# v_g: -0.012
# Estimating standard error
# v_g: 0.064 (0.029)
# Estimating variance of phenotypic variance estimate
# v_g/v_y: 0.608 (0.0822)
# 0.00018905554721026713
# 0.00017999936504039198
# Estimating covariance between genetic variance and phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 8216 individuals included
# 8216 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Estimating covariance between genetic variance and phenotypic variance estimate
# Computing regression estimate
# -1.1499694105003498e-05
# 0.09514888917352382
# v: 0.34
# Phenotypic variance estimate: 1.033
# Estimating heritability
# 118 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 0.00010900159691934361
# 0.60949075164665
# v_g: 1.175
# Estimating standard error
# v_g: 1.175 (1.166)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 1.137 (1.1279)
# v_g/v_y: 0.015 (0.0282)
# v_g/v_y: 0.185 (0.0372)
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 7802 individuals included
# 7802 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v_g: 0.023
# Estimating standard error
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 7904 individuals included
# 7904 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.binv_g: 0.339 (0.056)
# Estimating variance of phenotypic variance estimate
#
# v_g/v_y: 0.063 (0.0283)
# v_g: 0.386
# Estimating standard error
# v_g: -0.008 (0.014)
# Estimating variance of phenotypic variance estimate
# v_g: 0.107 (0.032)
# Estimating variance of phenotypic variance estimate
# Computing regression estimate
# -1.189026857946285e-05
# 0.09641731035124956
# v_g: 0.193 (0.05)
# Estimating variance of phenotypic variance estimate
# v: 0.652
# Phenotypic variance estimate: 0.848
# Estimating heritability
# 118 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 0.00010936808541307612
# 0.6175704603705345
# v_g: 1.434
# Estimating standard error
# v_g: 1.434 (0.998)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 1.692 (1.1703)
# v_g: 0.115 (0.032)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 8017 individuals included
# 8017 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v_g: 0.187 (0.04)
# Estimating variance of phenotypic variance estimate
# v_g: 0.13 (0.032)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.341 (0.055)
# Estimating covariance between genetic variance and phenotypic variance estimate
# Computing regression estimate
# -1.189026857946285e-05
# 0.09641731035124956
# v_g/v_y: 0.106 (0.0313)
# v: 0.297
# Phenotypic variance estimate: 0.909
# Estimating heritability
# 118 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 0.00010936808541307612
# 0.6175704603705345
# v_g: 0.899
# Estimating standard error
# v_g: 0.899 (1.032)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.99 (1.1347)
# Estimating covariance between genetic variance and phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: -0.011 (0.0188)
# v_g: 0.206 (0.036)
# Estimating variance of phenotypic variance estimate
# v_g: 0.054 (0.026)
# Estimating variance of phenotypic variance estimate
# v_g/v_y: 0.187 (0.0482)
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 6861 individuals included
# 6861 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 7921 individuals included
# 7921 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v_g/v_y: 0.13 (0.0321)
# v_g/v_y: 0.187 (0.0395)
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 8137 individuals included
# 8137 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v_g/v_y: 0.115 (0.0315)
# Computing regression estimate
# -1.189026857946285e-05
# 0.09641731035124956
# v: -0.167
# Phenotypic variance estimate: 0.615
# Estimating heritability
# 118 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 0.00010936808541307612
# 0.6175704603705345
# v_g: -0.095
# Estimating standard error
# v_g: -0.095 (0.674)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: -0.154 (1.0951)
# Estimating covariance between genetic variance and phenotypic variance estimate
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 7916 individuals included
# 7916 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Estimating covariance between genetic variance and phenotypic variance estimate
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 8229 individuals included
# 8229 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 8137 individuals included
# 8137 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 6861 individuals included
# 6861 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v_g/v_y: 0.205 (0.0353)
# v_g/v_y: 0.053 (0.0252)
# v_g: -0.012 (0.022)
# Estimating variance of phenotypic variance estimate
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 8236 individuals included
# 8236 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 8137 individuals included
# 8137 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: -0.011 (0.0209)
# v_g: 0.386 (0.052)
# Estimating variance of phenotypic variance estimate
# Computing regression estimate
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 8137 individuals included
# 8137 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v_g: 0.023 (0.018)
# Estimating variance of phenotypic variance estimate
# -1.2964945947330074e-09
# 0.00017743208372231862
# Estimating covariance between genetic variance and phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v: 0.865
# Phenotypic variance estimate: 1.001
# Estimating heritability
# Computing regression estimate
# 35800 pairs with relatedness >0.05 excluded
# Computing regression estimate
# Computing regression estimate
# -1.5611469826872235e-09
# 1.2806932870055912e-07
# -1.5559621064368223e-09
# 0.00019028846134011595
# v_g/v_y: 0.447 (0.0593)
# 0.0008037255030419583
# 0.000195641435241534
# v_g/v_y: 0.022 (0.0169)
# Computing regression estimate
# v: 0.281
# Phenotypic variance estimate: 0.995
# v_g: 0.675
# Estimating standard error
# v: 0.143
# Phenotypic variance estimate: 1.016
# Estimating heritability
# -1.4141387081505345e-09
# 33236 pairs with relatedness >0.05 excluded
# Computing regression estimate
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 7908 individuals included
# 7908 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# 0.00018572819615456882
# Estimating heritability
# 32392 pairs with relatedness >0.05 excluded
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 8137 individuals included
# 8137 individuals with both relatedness and trait information
# Computing regression estimate
# v_g: 0.675 (0.119)
# Estimating variance of phenotypic variance estimate
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# 1.385520548578901e-07
# Estimating covariance between genetic variance and phenotypic variance estimate
# v: 0.183
# Phenotypic variance estimate: 1.069
# 0.0008682147767577753
# v_g/v_y: 0.675 (0.1154)
# Computing regression estimate
# Estimating heritability
# 1.4234058176848626e-07
# 34296 pairs with relatedness >0.05 excluded
# Computing regression estimate
# v_g: 0.219
# Estimating standard error
# -2.926628098083683e-09
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2669 individuals included
# 2669 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# 0.0008911495095565002
# 0.00024871472136379306
# v_g: 0.219 (0.063)
# Estimating variance of phenotypic variance estimate
# 1.3485751804728628e-07
# Computing regression estimate
# v: 0.502
# Phenotypic variance estimate: 1.014
# ...
# Estimating covariance between genetic variance and phenotypic variance estimate
# Estimating heritability
# Computing regression estimate
# v_g: 0.44 (0.091)
# Estimating variance of phenotypic variance estimate
# 33352 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 0.00018053290035280009
# v_g/v_y: 0.018 (0.0531)
# Estimating covariance between genetic variance and phenotypic variance estimate
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2508 individuals included
# 2508 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Computing regression estimate
# v_g/v_y: 0.434 (0.0877)
# Computing regression estimate
# Computing regression estimate
# IDs of 19982 individuals read for relatedness matrices
#
# Computing regression estimate
# Non-missing phenotypes of 2638 individuals included
# 2638 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# 1.380088584400284e-07
# -1.3297949435699776e-09
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2228 individuals included
# 2228 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v: 0.003
# Phenotypic variance estimate: 0.835
# -1.5044971865960395e-09
# 0.00018053290035280009
# 0.0008645523080834211
# -2.926628098083683e-09
# -1.3297949435699776e-09
# 0.000190054313768003
# -1.288652210973344e-09
# Estimating heritability
# 0.00024871472136379306
# 35192 pairs with relatedness >0.05 excluded
# Computing regression estimate
# v_g: 0.132
# Estimating standard error
# 0.00018053290035280009
# 0.0001768146042605659
# v: 0.324
# Phenotypic variance estimate: 0.983
# v: 0.183
# Phenotypic variance estimate: 1.078
# 1.3082813795479516e-07
# Estimating heritability
# v: 0.437
# Phenotypic variance estimate: 0.951
# 35192 pairs with relatedness >0.05 excluded
# Estimating heritability
# Computing regression estimate
# v: 0.1
# Phenotypic variance estimate: 1.067
# 25094 pairs with relatedness >0.05 excluded
# v_g: 0.132 (0.064)
# Estimating variance of phenotypic variance estimate
# Computing regression estimate
# v: 0.195
# Phenotypic variance estimate: 0.963
# 0.0008194797107421915
# Estimating covariance between genetic variance and phenotypic variance estimate
# Estimating heritability
# 33300 pairs with relatedness >0.05 excluded
# Estimating heritability
# Computing regression estimate
# 1.8248674781195426e-07
# v_g/v_y: 0.114 (0.055)
# 35192 pairs with relatedness >0.05 excluded
# Computing regression estimate
# Estimating heritability
# 1.3082813795479516e-07
# 0.0011525335769035248
# 35964 pairs with relatedness >0.05 excluded
# v_g: 0.009
# Estimating standard error
# Computing regression estimate
# Computing regression estimate
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2548 individuals included
# 2548 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# 0.0008194797107421915
# 1.3814270531388512e-07
# 1.3082813795479516e-07
# v_g: 0.196
# Estimating standard error
# v_g: 0.009 (0.034)
# Estimating variance of phenotypic variance estimate
# 0.0008656106226975571
# -1.2852250636067867e-09
# 0.0008194797107421915
# 1.277916390018993e-07
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g: 0.196 (0.065)
# Estimating variance of phenotypic variance estimate
# v_g: 0.271
# Estimating standard error
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.01 (0.0407)
# 0.00017647976858144556
# 0.000801251452245992
# v_g/v_y: 0.182 (0.0596)
# v_g: 0.149
# Estimating standard error
# v_g: -0.004
# Estimating standard error
# v_g: 0.067
# Estimating standard error
# v: 0.252
# Phenotypic variance estimate: 0.974
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2228 individuals included
# 2228 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2651 individuals included
# 2651 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Estimating heritability
# 36022 pairs with relatedness >0.05 excluded
# v_g: 0.271 (0.065)
# Estimating variance of phenotypic variance estimate
# Computing regression estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g: 0.149 (0.076)
# Estimating variance of phenotypic variance estimate
# v_g/v_y: 0.276 (0.0656)
# 1.276077670705059e-07
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.156 (0.0792)
# 0.0007999430543096641
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2651 individuals included
# 2651 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Computing regression estimate
# v_g: -0.004 (0.05)
# Estimating variance of phenotypic variance estimate
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2545 individuals included
# 2545 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# v_g: 0.067 (0.053)
# Estimating variance of phenotypic variance estimate
# v_g: 0.192
# Estimating standard error
# Estimating covariance between genetic variance and phenotypic variance estimate
# -1.3297949435699776e-09
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: -0.004 (0.0466)
# v_g/v_y: 0.069 (0.0546)
# 0.00018053290035280009
# v_g: 0.192 (0.058)
# Estimating variance of phenotypic variance estimate
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2651 individuals included
# IDs of 19982 individuals read for relatedness matrices
#
# 2651 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Non-missing phenotypes of 2675 individuals included
# 2675 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Computing regression estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v: 0.066
# Phenotypic variance estimate: 1.066
# v_g/v_y: 0.197 (0.0591)
# Estimating heritability
# -1.3297949435699776e-09
# 35192 pairs with relatedness >0.05 excluded
# Computing regression estimate
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2678 individuals included
# 2678 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# 0.00018053290035280009
# Computing regression estimate
# -1.3314124720651996e-07
# 0.0011501649231083824
# v: 0.878
# Phenotypic variance estimate: 1.044
# 1.3082813795479516e-07
# Estimating heritability
# 8860 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.3287837932471224e-06
# 0.007619980818285945
# v_g: 0.665
# Estimating standard error
# v: -0.015
# Phenotypic variance estimate: 1.224
# v_g: 0.665 (0.216)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.636 (0.2028)
# 0.0008194797107421915
# Estimating heritability
# 35192 pairs with relatedness >0.05 excluded
# Computing regression estimate
# v_g: 0.026
# Estimating standard error
# v_g: 0.026 (0.047)
# Estimating variance of phenotypic variance estimate
# 1.3082813795479516e-07
# Estimating covariance between genetic variance and phenotypic variance estimate
# Computing regression estimate
# 0.0008194797107421915
# v_g/v_y: 0.024 (0.0443)
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2651 individuals included
# 2651 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# -1.5247607115005816e-09
# v_g: 0.002
# Estimating standard error
# 0.00019029906335724475
# v_g: 0.002 (0.049)
# Estimating variance of phenotypic variance estimate
# Computing regression estimate
# -1.3611370913615321e-07
# 0.0011727342457649797
# v: 0.529
# Phenotypic variance estimate: 0.871
# Estimating covariance between genetic variance and phenotypic variance estimate
# Computing regression estimate
# v: 0.202
# Phenotypic variance estimate: 0.988
# -1.5408518134477723e-07
# 0.0012726382972377609
# Estimating heritability
# 8684 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.3671696635128289e-06
# v: 0.07
# Phenotypic variance estimate: 0.838
# v_g/v_y: 0.002 (0.0398)
# 0.007801892626358071
# v_g: 0.038
# Estimating standard error
# Estimating heritability
# 7926 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.5092430829564182e-06
# v_g: 0.038 (0.14)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.038 (0.1412)
# 0.00862020975415525
# v_g: 0.052
# Estimating standard error
# v_g: 0.052 (0.115)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.062 (0.1376)
# Computing regression estimate
# Estimating heritability
# -1.879225416724562e-07
# 0.0016532540494694455
# 33254 pairs with relatedness >0.05 excluded
# v: 0.384
# Phenotypic variance estimate: 1.111
# Computing regression estimate
# Estimating heritability
# 6078 pairs with relatedness >0.05 excluded
# Computing regression estimate
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2651 individuals included
# 2651 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# 1.9054929835926224e-06
# 0.010955197321638275
# v_g: 0.456
# Estimating standard error
# v_g: 0.456 (0.197)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.411 (0.176)
# Computing regression estimate
# -1.4947531866810144e-07
# 0.0012277149882008811
# v: 0.23
# Phenotypic variance estimate: 0.65
# Estimating heritability
# 8186 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.461659333480783e-06
# 0.008352419725182388
# 1.3845398253364822e-07
# v_g: 0.395
# Estimating standard error
# v_g: 0.395 (0.104)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.608 (0.1588)
# 0.0008673298738422839
# Computing regression estimate
# -1.5098589443218518e-07
# 0.0012301400478662051
# v: 0.361
# Phenotypic variance estimate: 0.85
# Estimating heritability
# 8156 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.4658412875888382e-06
# v_g: 0.442
# Estimating standard error
# 0.008390848949388196
# v_g: 0.308
# Estimating standard error
# v_g: 0.308 (0.143)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.362 (0.1665)
# v_g: 0.442 (0.082)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.508 (0.0923)
# IDs of 19982 individuals read for relatedness matrices
#
# Non-missing phenotypes of 2542 individuals included
# 2542 individuals with both relatedness and trait information
# Reading /data/jerrylee/data/GS/GRM/GS_GWAS.grm.bin
# Computing regression estimate
# -1.3694142525342055e-07
# 0.0011519630469521186
# v: 0.001
# Phenotypic variance estimate: 0.003
# Computing regression estimate
# -1.879225416724562e-07
# 0.0016532540494694455
# Estimating heritability
# 8818 pairs with relatedness >0.05 excluded
# Computing regression estimate
# v: 0.186
# Phenotypic variance estimate: 0.892
# 1.3481653851703974e-06
# 0.007722609697026021
# Estimating heritability
# 6078 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.9054929835926224e-06
# v_g: 0.001
# Estimating standard error
# 0.010955197321638275
# v_g: -0.058
# Estimating standard error
# v_g: 0.001 (0.0)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.314 (0.1606)
# v_g: -0.058 (0.147)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: -0.066 (0.1647)
# Computing regression estimate
# Computing regression estimate
# -1.3694142525342055e-07
# 0.0011519630469521186
# -1.49717538399709e-07
# 0.0012309545608494138
# v: 0.386
# Phenotypic variance estimate: 0.968
# v: 0.405
# Phenotypic variance estimate: 0.589
# Estimating heritability
# Estimating heritability
# 8168 pairs with relatedness >0.05 excluded
# 8818 pairs with relatedness >0.05 excluded
# Computing regression estimate
# Computing regression estimate
# Computing regression estimate
# 1.4659051504923026e-06
# 1.3481653851703974e-06
# 0.008371860366353194
# 0.007722609697026021
# -1.3694142525342055e-07
# 0.0011519630469521186
# v_g: 0.099
# Estimating standard error
# v_g: 0.17
# Estimating standard error
# v_g: 0.099 (0.116)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g: 0.17 (0.154)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.176 (0.1587)
# v_g/v_y: 0.168 (0.1957)
# v: 0.109
# Phenotypic variance estimate: 1.046
# Estimating heritability
# 8818 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.3481653851703974e-06
# 0.007722609697026021
# v_g: -0.223
# Estimating standard error
# v_g: -0.223 (0.138)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: -0.213 (0.1325)
# Computing regression estimate
# -1.329683523380733e-07
# 0.0011434984176493979
# v: 0.344
# Phenotypic variance estimate: 0.699
# Estimating heritability
# 8942 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.3233661806370383e-06
# 0.007583820507827708
# v_g: 0.317
# Estimating standard error
# v_g: 0.317 (0.117)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.454 (0.166)
# Computing regression estimate
# -1.3265129008372493e-07
# 0.001140537629262275
# v: 0.429
# Phenotypic variance estimate: 0.836
# Estimating heritability
# 8956 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.3202626682409199e-06
# 0.007567394057138283
# v_g: 0.322
# Estimating standard error
# v_g: 0.322 (0.142)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.385 (0.1681)
# Computing regression estimate
# -1.3694142525342055e-07
# 0.0011519630469521186
# v: -0.005
# Phenotypic variance estimate: 0.894
# Estimating heritability
# 8818 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.3481653851703974e-06
# 0.007722609697026021
# v_g: 0.024
# Estimating standard error
# v_g: 0.024 (0.111)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.027 (0.1239)
# Computing regression estimate
# -1.5051961416738523e-07
# 0.0012345992540894592
# v: 0.453
# Phenotypic variance estimate: 0.746
# Estimating heritability
# 8146 pairs with relatedness >0.05 excluded
# Computing regression estimate
# Computing regression estimate
# 1.4666656015565865e-06
# 0.008390830784284625
# -1.3694142525342055e-07
# v_g: 0.382
# Estimating standard error
# 0.0011519630469521186
# v_g: 0.382 (0.14)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.512 (0.1851)
# v: 0.752
# Phenotypic variance estimate: 0.541
# Estimating heritability
# 8818 pairs with relatedness >0.05 excluded
# Computing regression estimate
# 1.3481653851703974e-06
# 0.007722609697026021
# v_g: 0.124
# Estimating standard error
# v_g: 0.124 (0.15)
# Estimating variance of phenotypic variance estimate
# Estimating covariance between genetic variance and phenotypic variance estimate
# v_g/v_y: 0.23 (0.2739)

# %% [markdown]
# # merge results

# %%
df_results = pd.DataFrame(columns=[
    "cohort", "phenotype", "DOR", "estimate", "std_error"])

for cohort in ["UKB", "GS"]:
    path = f"/data/jerrylee/pjt/BIGFAM.v.2.0/data/other-methods/RDR/{cohort}"
    pheno_fns = os.listdir(path)
    
    for pheno_fn in pheno_fns:
        tmp = pd.read_csv(f"{path}/{pheno_fn}", sep='\t')
        dor = pheno_fn.split(".")[-2]
        pheno = pheno_fn.split(".")[0]
        estimate, se = tmp[tmp['Unnamed: 0'] == 'h2'][['Estimate', 'S.E.']].values[0]
        
        df_results = df_results.append({
            "cohort": cohort,
            "phenotype": pheno,
            "DOR": dor,
            "estimate": estimate,
            "std_error": se
        }, ignore_index=True)

# %%
(df_results
 .sort_values(by=["cohort", "phenotype", "DOR"])
 .reset_index(drop=True)
 .to_csv(f"/data/jerrylee/pjt/BIGFAM.v.2.0/data/other-methods/RDR/RDR.raw.tsv", sep='\t', index=False)
)

# %%
df_results
# Out:
#     cohort                   phenotype DOR  estimate  std_error
# 0      UKB  Leg_predicted_mass__right_   2  0.431320   0.096937
# 1      UKB     Impedance_of_leg__left_   2  0.294856   0.092966
# 2      UKB           Neutrophill_count   2  0.197015   0.085134
# 3      UKB          Potassium_in_urine   2  0.020760   0.077551
# 4      UKB      Neutrophill_percentage   3  0.152399   0.021078
# ..     ...                         ...  ..       ...        ...
# 433     GS                    expected   1  0.608415   0.082247
# 434     GS                QRS_duration   1  0.017542   0.019264
# 435     GS                 PR_interval   3  0.022232   0.123828
# 436     GS                   ECG_Count   1  0.022207   0.016893
# 437     GS                        hips   2  0.329735   0.400255
#
# [438 rows x 5 columns]

# %%
# IVW 계산을 위한 그룹별 함수 정의
def calculate_ivw(group):
    weights = 1 / (group['std_error'] ** 2)
    ivw_estimate = sum(group['estimate'] * weights) / sum(weights)
    ivw_se = np.sqrt(1 / sum(weights))
    
    return pd.Series({
        'ivw_estimate': ivw_estimate,
        'ivw_se': ivw_se,
        'n_dor': len(group)  # DOR 개수 확인용
    })

# IVW 계산 실행
df_ivw = (df_results
    .groupby(['cohort', 'phenotype'])
    .apply(calculate_ivw)
    .reset_index()
)

# %%
df_ivw
# Out:
#     cohort                           phenotype  ivw_estimate    ivw_se  n_dor
# 0       GS                          Creat_mgdl      0.173045  0.039223    3.0
# 1       GS                          Creatinine      0.178608  0.040295    3.0
# 2       GS                           ECG_Count      0.019802  0.015527    3.0
# 3       GS                                 FEF      0.244723  0.037647    3.0
# 4       GS                                 FEV      0.370123  0.045040    3.0
# ..     ...                                 ...           ...       ...    ...
# 141    UKB                              Weight      0.291792  0.022395    3.0
# 142    UKB  White_blood_cell__leukocyte__count      0.145200  0.016690    3.0
# 143    UKB            Whole_body_fat-free_mass      0.394194  0.025403    3.0
# 144    UKB                 Whole_body_fat_mass      0.257473  0.021227    3.0
# 145    UKB               Whole_body_water_mass      0.389203  0.025226    3.0
#
# [146 rows x 5 columns]

# %%
(
    df_ivw
    .drop(columns=["n_dor"])
    .to_csv("/data/jerrylee/pjt/BIGFAM.v.2.0/data/other-methods/RDR.ivw.tsv", 
              sep='\t', index=False)
)
