# %%
import os

# %%
cmd = "/data/jerrylee/tools/gcta64 --bfile {bfile_prefix} --make-grm --thread-num 40 --out {output_prefix}".format(
    bfile_prefix="/data/jerrylee/data/GS/GWAS/GS_GWAS",
    output_prefix="/data/jerrylee/data/GS/GWAS/GRM"
)

# %%
os.system(cmd)
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version 1.94.0 beta Linux
# * (C) 2010-present, Jian Yang, The University of Queensland
# * Please report bugs to Jian Yang <jian.yang.qt@gmail.com>
# *******************************************************************
# Analysis started at 11:19:58 KST on Thu May 02 2024.
# Hostname: h4
#
# Options:
#
# --bfile /data/jerrylee/data/GS/GWAS/GS_GWAS
# --make-grm
# --thread-num 40
# --out /data/jerrylee/data/GS/GWAS/GS_GWAS
#
# The program will be running with up to 40 threads.
# Note: GRM is computed using the SNPs on the autosomes.
# Reading PLINK FAM file from [/data/jerrylee/data/GS/GWAS/GS_GWAS.fam]...
# 19982 individuals to be included from FAM file.
# 19982 individuals to be included. 8216 males, 11766 females, 0 unknown.
# Reading PLINK BIM file from [/data/jerrylee/data/GS/GWAS/GS_GWAS.bim]...
# 561125 SNPs to be included from BIM file(s).
# ...
