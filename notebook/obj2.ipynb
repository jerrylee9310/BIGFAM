# %%
# GOAL :: partitioning X heritability

# %%
import pandas as pd
import numpy as np
import os
from tqdm import tqdm
import sys
import sys; sys.path.append("/data/jerrylee/pjt/BIGFAM.v.0.1")

from BIGFAM import obj2, tools
import importlib

# %%
source = "GS"

# %% [markdown]
# # Step 1. Load data

# %%
# load FR-reg
frreg_path = f"/data/jerrylee/pjt/BIGFAM.v.0.1/data/{source}/frreg/REL"
fns = os.listdir(frreg_path)
len(fns)
# Out:
# 40

# %% [markdown]
# # Step 2. Estimate X

# %%
output_path = f"/data/jerrylee/pjt/BIGFAM.v.0.1/data/{source}/obj2"

# %% [markdown]
# ## Step 2.1. X in all

# %%
for ii, fn in enumerate(tqdm(fns)):
    pheno = fn.split(".")[0]
    print(f"[{ii+1}/{len(fns)}] {pheno}")
    
    # load FR-reg results
    df_frreg = pd.read_csv(f"{frreg_path}/{fn}", 
                           delim_whitespace=True)
    df_x = obj2.estimateX(df_frreg,
                          n_resample=100,
                          alpha_dicts={"type": "eta", "weight":-3},
                          regout_bin=["DOR", "sex_type"])
    
    if df_x.shape[0] > 0:
        # save raw results
        df_x.to_csv(f"{output_path}/{pheno}.X_raw",
                    sep='\t',
                    index=False)
        tools.raw2long(df_x, params=["eta", "alpha", "X"]).to_csv(
            f"{output_path}/{pheno}.X",
            sep='\t',
            index=False)
# Out:
#   0%|          | 0/111 [00:00<?, ?it/s]
# [1/111] Weight
#   1%|          | 1/111 [00:05<09:46,  5.33s/it]
# [2/111] Hand_grip_strength__left_
#   2%|▏         | 2/111 [00:10<09:41,  5.33s/it]
# [3/111] Impedance_of_whole_body
#   3%|▎         | 3/111 [00:15<09:35,  5.33s/it]
# [4/111] Arm_fat-free_mass__right_
#   4%|▎         | 4/111 [00:21<09:30,  5.33s/it]
# [5/111] Platelet_distribution_width
#   5%|▍         | 5/111 [00:26<09:23,  5.32s/it]
# [6/111] Forced_vital_capacity__FVC__Z-score
#   5%|▌         | 6/111 [00:31<09:17,  5.31s/it]
# [7/111] FEV1__FVC_ratio_Z-score
#   6%|▋         | 7/111 [00:37<09:12,  5.32s/it]
# [8/111] Sodium_in_urine
#   7%|▋         | 8/111 [00:42<09:06,  5.31s/it]
# [9/111] Leg_predicted_mass__right_
#   8%|▊         | 9/111 [00:47<09:02,  5.31s/it]
# [10/111] Mean_sphered_cell_volume
#   9%|▉         | 10/111 [00:53<08:57,  5.33s/it]
# [11/111] Waist_circumference
#  10%|▉         | 11/111 [00:58<08:51,  5.32s/it]
# [12/111] Apolipoprotein_A
#  11%|█         | 12/111 [01:04<08:54,  5.40s/it]
# [13/111] Arm_fat_percentage__right_
#  12%|█▏        | 13/111 [01:09<08:47,  5.38s/it]
# [14/111] Mean_corpuscular_haemoglobin_concentration
#  13%|█▎        | 14/111 [01:14<08:39,  5.36s/it]
# [15/111] Body_fat_percentage
#  14%|█▎        | 15/111 [01:20<08:32,  5.34s/it]
# [16/111] Platelet_count
#  14%|█▍        | 16/111 [01:25<08:25,  5.32s/it]
# [17/111] Albumin
#  15%|█▌        | 17/111 [01:30<08:19,  5.31s/it]
# [18/111] LDL_direct
# [78/111] Immature_reticulocyte_fraction
#  70%|███████   | 78/111 [06:55<02:55,  5.31s/it]
# [79/111] Reticulocyte_percentage
#  71%|███████   | 79/111 [07:00<02:49,  5.30s/it]
# [80/111] Seated_height
#  72%|███████▏  | 80/111 [07:06<02:44,  5.30s/it]
# [81/111] Forced_vital_capacity__FVC_
#  73%|███████▎  | 81/111 [07:11<02:39,  5.30s/it]
# [82/111] Haemoglobin_concentration
#  74%|███████▍  | 82/111 [07:16<02:33,  5.29s/it]
# [83/111] Impedance_of_leg__right_
#  75%|███████▍  | 83/111 [07:21<02:28,  5.29s/it]
# [84/111] Total_bilirubin
#  76%|███████▌  | 84/111 [07:27<02:23,  5.30s/it]
# [85/111] Reticulocyte_count
#  77%|███████▋  | 85/111 [07:32<02:17,  5.30s/it]
# [86/111] IGF-1
#  77%|███████▋  | 86/111 [07:38<02:13,  5.34s/it]
# [87/111] Standing_height
#  78%|███████▊  | 87/111 [07:43<02:07,  5.31s/it]
# [88/111] Impedance_of_arm__left_
#  79%|███████▉  | 88/111 [07:48<02:02,  5.31s/it]
# [89/111] SHBG
#  80%|████████  | 89/111 [07:53<01:56,  5.30s/it]
# [90/111] Trunk_fat-free_mass
#  81%|████████  | 90/111 [07:59<01:51,  5.30s/it]
# [91/111] Urea
#  82%|████████▏ | 91/111 [08:04<01:46,  5.30s/it]
# [92/111] White_blood_cell__leukocyte__count
#  83%|████████▎ | 92/111 [08:09<01:40,  5.30s/it]
# [93/111] Hand_grip_strength__right_
#  84%|████████▍ | 93/111 [08:15<01:35,  5.31s/it]
# [94/111] Estimated_sample_dilution_factor
#  85%|████████▍ | 94/111 [08:20<01:30,  5.33s/it]
# [95/111] Mean_corpuscular_haemoglobin
#  86%|████████▌ | 95/111 [08:25<01:25,  5.32s/it]
# [96/111] Alanine_aminotransferase
#  86%|████████▋ | 96/111 [08:31<01:19,  5.32s/it]
# [97/111] Body_mass_index__BMI_
#  87%|████████▋ | 97/111 [08:36<01:14,  5.33s/it]
# [98/111] Direct_bilirubin
#  88%|████████▊ | 98/111 [08:41<01:09,  5.32s/it]
# [99/111] Forced_expiratory_volume_in_1-second__FEV1_,_Best_measure
#  89%|████████▉ | 99/111 [08:47<01:03,  5.32s/it]
# [100/111] Trunk_fat_percentage
#  90%|█████████ | 100/111 [08:52<00:58,  5.33s/it]
# [101/111] Potassium_in_urine
#  91%|█████████ | 101/111 [08:57<00:53,  5.37s/it]
# [102/111] Creatinine
#  92%|█████████▏| 102/111 [09:03<00:48,  5.36s/it]
# [103/111] Arm_fat-free_mass__left_
#  93%|█████████▎| 103/111 [09:08<00:42,  5.34s/it]
# [104/111] Forced_expiratory_volume_in_1-second__FEV1__Z-score
#  94%|█████████▎| 104/111 [09:13<00:37,  5.32s/it]
# [105/111] Whole_body_fat_mass
#  95%|█████████▍| 105/111 [09:19<00:31,  5.32s/it]
# [106/111] Gamma_glutamyltransferase
#  95%|█████████▌| 106/111 [09:24<00:26,  5.33s/it]
# [107/111] Alkaline_phosphatase
#  96%|█████████▋| 107/111 [09:29<00:21,  5.32s/it]
# [108/111] Leg_predicted_mass__left_
#  97%|█████████▋| 108/111 [09:35<00:15,  5.31s/it]
# [109/111] Eosinophill_percentage
#  98%|█████████▊| 109/111 [09:40<00:10,  5.31s/it]
# [110/111] Mean_corpuscular_volume
#  99%|█████████▉| 110/111 [09:45<00:05,  5.30s/it]
# [111/111] Triglycerides
# 100%|██████████| 111/111 [09:50<00:00,  5.32s/it]

# %% [markdown]
# ## Step 2.2 X in male and female

# %%
for ii, fn in enumerate(tqdm(fns)):
    pheno = fn.split(".")[0]
    print(f"[{ii+1}/{len(fns)}] {pheno}")
    
    # load FR-reg results
    df_frreg = pd.read_csv(f"{frreg_path}/{fn}", 
                           delim_whitespace=True)
    df_x = obj2.estimateXmXf(df_frreg,
                             alpha_dicts={"type": "eta", "weight":-2})
    if df_x.shape[0] > 0:
        # save raw results
        df_x.to_csv(f"{output_path}/{pheno}.XmXf_raw",
                    sep='\t',
                    index=False)
        df_x_sums = tools.raw2long(df_x, params=["eta", "alpha", "Xmale", "Xfemale"])
        
        df_x_sums.to_csv(
            f"{output_path}/{pheno}.XmXf",
            sep='\t',
            index=False)
        
        print(pheno)
        print(df_x_sums)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# [1/40] avg_dia
# L2 weight is negative...
#   2%|▎         | 1/40 [00:06<04:17,  6.61s/it]
# avg_dia
#      param    median  lower(2.5%)  upper(97.5%)
# 0      eta  0.224403     0.091314      0.357051
# 1    alpha  4.456276     2.800719     11.061137
# 2    Xmale  0.000001     0.000001      0.000001
# 3  Xfemale  0.000001     0.000001      0.000001
# [2/40] height
#   5%|▌         | 2/40 [00:12<04:00,  6.32s/it]
# height
#      param    median  lower(2.5%)  upper(97.5%)
# 0      eta  1.132147     0.705010      1.601842
# 1    alpha  0.883293     0.624290      1.418451
# 2    Xmale  0.000001     0.000001      0.000001
# 3  Xfemale  0.000001     0.000001      0.000001
# [3/40] weight
#   8%|▊         | 3/40 [00:18<03:51,  6.25s/it]
# weight
#      param    median  lower(2.5%)  upper(97.5%)
# 0      eta  0.513497     0.098561      0.757453
# 1    alpha  1.947492     1.320613     10.289342
# 2    Xmale  0.000001     0.000001      0.000001
# 3  Xfemale  0.000001     0.000001      0.000001
# [4/40] max_leg
#  10%|█         | 4/40 [00:25<03:51,  6.42s/it]
# max_leg
#      param    median  lower(2.5%)  upper(97.5%)
# 0      eta  0.522953     0.366546      0.703783
# 1    alpha  1.912218     1.421002      2.728253
# 2    Xmale  0.000001     0.000001      0.000001
# 3  Xfemale  0.000001     0.000001      0.000001
# [5/40] avg_hr
#  12%|█▎        | 5/40 [00:32<03:47,  6.50s/it]
# avg_hr
#      param    median  lower(2.5%)  upper(97.5%)
# 0      eta  0.633400     0.431005      0.778648
# 1    alpha  1.578783     1.284312      2.320720
# 2    Xmale  0.000001     0.000001      0.000001
# 3  Xfemale  0.000001     0.000001      0.000001
# [6/40] avg_sys
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
#  15%|█▌        | 6/40 [00:38<03:38,  6.42s/it]
# avg_sys
#      param     median  lower(2.5%)  upper(97.5%)
# 0      eta   0.093718     0.007377      0.281069
# 1    alpha  10.671397     3.559393    163.070324
# 2    Xmale   0.000001     0.000001      0.000001
# 3  Xfemale   0.000001     0.000001      0.000001
# [7/40] PR_interval
#  18%|█▊        | 7/40 [00:45<03:34,  6.49s/it]
# PR_interval
#      param    median  lower(2.5%)  upper(97.5%)
# 0      eta  0.506831     0.357462      0.648186
# 1    alpha  1.973050     1.542767      2.797529
# 2    Xmale  0.000001     0.000001      0.000001
# 3  Xfemale  0.000001     0.000001      0.000001
# [8/40] Glucose
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
#  20%|██        | 8/40 [00:51<03:26,  6.44s/it]
# Glucose
#      param    median  lower(2.5%)  upper(97.5%)
# 0      eta  0.101658     0.003230      0.269440
# 1    alpha  9.836947     3.711752    309.776313
# 2    Xmale  0.000001     0.000001      0.000001
# 3  Xfemale  0.000001     0.000001      0.000001
# [9/40] HDL_cholesterol
#  22%|██▎       | 9/40 [00:58<03:21,  6.51s/it]
# HDL_cholesterol
#      param    median  lower(2.5%)  upper(97.5%)
# 0      eta  0.762297     0.600317      0.915028
# 1    alpha  1.311830     1.092863      1.665983
# 2    Xmale  0.000001     0.000001      0.000001
# 3  Xfemale  0.000001     0.000001      0.000001
# [10/40] Total_cholesterol
#  25%|██▌       | 10/40 [01:04<03:16,  6.54s/it]
# Total_cholesterol
#      param    median  lower(2.5%)  upper(97.5%)
# 0      eta  0
#      param    median  lower(2.5%)  upper(97.5%)
# 0      eta  0.984701     0.498304      1.501437
# 1    alpha  1.015539     0.666072      2.038529
# 2    Xmale  0.000001     0.000001      0.000001
# 3  Xfemale  0.000001     0.000001      0.000001
# [28/40] waist
#  70%|███████   | 28/40 [03:02<01:16,  6.41s/it]
# waist
#      param    median  lower(2.5%)  upper(97.5%)
# 0      eta  0.862015     0.472553      1.231247
# 1    alpha  1.160107     0.812210      2.116981
# 2    Xmale  0.000001     0.000001      0.000001
# 3  Xfemale  0.000001     0.000001      0.000001
# [29/40] LVMI_Rautaharju
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
#  72%|███████▎  | 29/40 [03:07<01:06,  6.05s/it]
# LVMI_Rautaharju
#      param     median  lower(2.5%)  upper(97.5%)
# 0      eta   0.019399     0.019399      0.019399
# 1    alpha  51.549091    51.549091     51.549091
# 2    Xmale   0.000001     0.000001      0.000001
# 3  Xfemale   0.000001     0.000001      0.000001
# [30/40] QRS_duration
#  75%|███████▌  | 30/40 [03:14<01:02,  6.24s/it]
# QRS_duration
#      param    median  lower(2.5%)  upper(97.5%)
# 0      eta  0.316743     0.132474      0.456462
# 1    alpha  3.157139     2.190801      7.555478
# 2    Xmale  0.000001     0.000001      0.000001
# 3  Xfemale  0.000001     0.000001      0.000001
# [31/40] T_axis
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
#  78%|███████▊  | 31/40 [03:19<00:53,  5.96s/it]
# T_axis
#      param     median  lower(2.5%)  upper(97.5%)
# 0      eta   0.022288     0.005181      0.176583
# 1    alpha  44.867194     7.930724    234.673036
# 2    Xmale   0.000001     0.000001      0.000001
# 3  Xfemale   0.000001     0.000001      0.000001
# [32/40] QTC_interval
#  80%|████████  | 32/40 [03:26<00:49,  6.17s/it]
# QTC_interval
#      param    median  lower(2.5%)  upper(97.5%)
# 0      eta  0.314247     0.122912      0.479295
# 1    alpha  3.182214     2.086403      8.136162
# 2    Xmale  0.000001     0.000001      0.000001
# 3  Xfemale  0.000001     0.000001      0.000001
# [33/40] Urea
#  82%|████████▎ | 33/40 [03:32<00:44,  6.33s/it]
# Urea
#      param    median  lower(2.5%)  upper(97.5%)
# 0      eta  0.186191     0.040039      0.396641
# 1    alpha  5.371675     2.545350     25.176399
# 2    Xmale  0.000001     0.000001      0.000001
# 3  Xfemale  0.000001     0.000001      0.000001
# [34/40] P_duration
#  85%|████████▌ | 34/40 [03:39<00:38,  6.43s/it]
# P_duration
#      param    median  lower(2.5%)  upper(97.5%)
# 0      eta  0.295490     0.127549      0.493168
# 1    alpha  3.384212     2.027757      7.841385
# 2    Xmale  0.000001     0.000001      0.000001
# 3  Xfemale  0.000001     0.000001      0.000001
# [35/40] body_fat
#  88%|████████▊ | 35/40 [03:45<00:31,  6.35s/it]
# body_fat
#      param    median  lower(2.5%)  upper(97.5%)
# 0      eta  0.960786     0.401845      1.420243
# 1    alpha  1.040833     0.704178      2.535106
# 2    Xmale  0.000001     0.000001      0.000001
# 3  Xfemale  0.000001     0.000001      0.000001
# [36/40] bmi
#  90%|█████████ | 36/40 [03:51<00:25,  6.30s/it]
# bmi
#      param    median  lower(2.5%)  upper(97.5%)
# 0      eta  0.596541     0.160770      0.993206
# 1    alpha  1.676331     1.006855      6.239542
# 2    Xmale  0.000001     0.000001      0.000001
# 3  Xfemale  0.000001     0.000001      0.000001
# [37/40] LVMI_Fhuwez
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
#  92%|█████████▎| 37/40 [03:58<00:19,  6.38s/it]
# LVMI_Fhuwez
#      param    median  lower(2.5%)  upper(97.5%)
# 0      eta  0.114090     0.018501      0.298450
# 1    alpha  8.764973     3.350643     54.049712
# 2    Xmale  0.000001     0.000001      0.000001
# 3  Xfemale  0.000001     0.000001      0.000001
# [38/40] Creatinine
#  95%|█████████▌| 38/40 [04:05<00:12,  6.47s/it]
# Creatinine
#      param    median  lower(2.5%)  upper(97.5%)
# 0      eta  0.946278     0.787395      1.159459
# 1    alpha  1.056772     0.862610      1.270488
# 2    Xmale  0.000001     0.000001      0.000001
# 3  Xfemale  0.000001     0.000001      0.000001
# [39/40] expected
#  98%|█████████▊| 39/40 [04:11<00:06,  6.53s/it]
# expected
#      param    median  lower(2.5%)  upper(97.5%)
# 0      eta  0.755532     0.559418      0.974368
# 1    alpha  1.323571     1.026437      1.788231
# 2    Xmale  0.000001     0.000001      0.000001
# 3  Xfemale  0.000001     0.000001      0.000001
# [40/40] P_axis
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# L2 weight is negative...
# 100%|██████████| 40/40 [04:17<00:00,  6.44s/it]
# P_axis
#      param     median  lower(2.5%)  upper(97.5%)
# 0      eta   0.052719     0.005849      0.179229
# 1    alpha  18.968338     5.672915    172.067799
# 2    Xmale   0.000001     0.000001      0.000001
# 3  Xfemale   0.000001     0.000001      0.000001
