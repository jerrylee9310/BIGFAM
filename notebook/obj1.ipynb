# %%
import pandas as pd
import numpy as np
import os
from tqdm import tqdm
import sys

import sys; sys.path.append("/data/jerrylee/pjt/BIGFAM.v.0.1")
from BIGFAM import obj1, tools
import importlib

# %%
importlib.reload(obj1)
# Out:
# <module 'BIGFAM.obj1' from '/data/jerrylee/pjt/BIGFAM.v.0.1/BIGFAM/obj1.py'>

# %% [markdown]
# # Step 1. Load FR-reg

# %%
# load FR-reg
frreg_path = "/data/jerrylee/pjt/BIGFAM.v.0.1/data/GS/frreg/DOR"
fns = os.listdir(frreg_path)
len(fns)
# Out:
# 27

# %% [markdown]
# # Step 2. FRLog-reg

# %%
frlog_path = "/data/jerrylee/pjt/BIGFAM.v.0.1/data/GS/FRLogreg"
gsw_path = "/data/jerrylee/pjt/BIGFAM.v.0.1/data/GS/obj1"

# %%
for ii, fn in enumerate(tqdm(fns)):
    pheno_name = fn.split(".")[0]
    # load FR-reg
    frreg_fn = f"{frreg_path}/{fn}"
    df_frreg = pd.read_csv(frreg_fn, delim_whitespace=True)
    
    # resampling FR-reg to compute CIs
    df_lmbds = obj1.resampleFrregCoefficients(df_frreg, n_resample=100)    
    
    # slope test(FRLog-reg)
    df_frlogreg = obj1.familialRelationshipLogRegression(df_lmbds)
    sig = obj1._slopeSig(df_frlogreg["slope"])
    
    # save slope test results
    savefn_slopetest = f"{frlog_path}/{pheno_name}.FRLOG"
    (tools.raw2long(df_frlogreg, params=["slope", "intercept"])
     .to_csv(savefn_slopetest, sep='\t', index=False))
    df_frlogreg.to_csv(savefn_slopetest + "_raw",  sep='\t', index=False)
    
    # prediction
    df_gsw = obj1.prediction(df_lmbds, sig, print_prog=True)
    # save prediction results 
    savefn_pred = f"{gsw_path}/{pheno_name}.GSW"
    (tools.raw2long(df_gsw, params=df_gsw.columns)
     .to_csv(savefn_pred, sep='\t', index=False))
    df_gsw.to_csv(savefn_pred + "_raw",  sep='\t', index=False)
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
# 1..2..3..
#   0%|          | 0/27 [00:39<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 21
#      18 df_frlogreg.to_csv(savefn_slopetest + "_raw",  sep='\t', index=False)
#      20 # prediction
# ---> 21 df_gsw = obj1.prediction(df_lmbds, sig, print_prog=True)
#      22 # save prediction results
#      23 savefn_pred = f"{output_path}/{pheno_name}.GSW"
#
# File /data/jerrylee/pjt/BIGFAM.v.0.1/BIGFAM/obj1.py:198, in prediction(df_lmbds, frlogreg_sig, n_repeat_cv, n_block, step_size, print_prog)
#     195 df_test = df_frreg_with_block[df_frreg_with_block["block"] == i_b].copy()
#     197 # grid search
# --> 198 df_preds = _gridSearch(df_train, df_test, w0_range)
#     199 df_best_pred = _getMin(df_preds)
#     201 df_res = pd.concat([df_res, df_best_pred], axis=0).reset_index(drop=True)
#
# File /data/jerrylee/pjt/BIGFAM.v.0.1/BIGFAM/obj1.py:87, in _gridSearch(df_train, df_test, w_range)
#      84 bnds = ((1e-6, 1), (1e-6, 1))
#      86 # in train data
# ---> 87 MODEL = minimize(
#      88     fun = _lossFunc,
#      89     x0 = x0,
#      90     args = [df_train, w],
#      91     bounds = bnds,
#      92     tol=1e-4
#      93 )
#      95 G_est, S1_est = MODEL.x
#      97 # in test data
#
# File ~/miniconda3/envs/BIGFAM/lib/python3.9/site-packages/scipy/optimize/_minimize.py:713, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     710     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     711                              **options)
#     712 elif meth == 'l-bfgs-b':
# --> 713     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     714                            callback=callback, **options)
#     715 elif meth == 'tnc':
#     716     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     717                         **options)
#
# File ~/miniconda3/envs/BIGFAM/lib/python3.9/site-packages/scipy/optimize/_lbfgsb_py.py:369, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     363 task_str = task.tobytes()
#     364 if task_str.startswith(b'FG'):
#     365     # The minimization routine wants f and g at the current x.
#     366     # Note that interruptions due to maxfun are postponed
#     367     # until the completion of the current minimization iteration.
#     368     # Overwrite f and g:
# --> 369     f, g = func_and_grad(x)
#     370 elif task_str.startswith(b'NEW_X'):
#     371     # new iteration
#     372     n_iterations += 1
#
# File ~/miniconda3/envs/BIGFAM/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:297, in ScalarFunction.fun_and_grad(self, x)
#     295     self._update_x_impl(x)
#     296 self._update_fun()
# --> 297 self._update_grad()
#     298 return self.f, self.g
#
# File ~/miniconda3/envs/BIGFAM/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:267, in ScalarFunction._update_grad(self)
#     265 def _update_grad(self):
#     266     if not self.g_updated:
# --> 267         self._update_grad_impl()
#     268         self.g_updated = True
#
# File ~/miniconda3/envs/BIGFAM/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:181, in ScalarFunction.__init__.<locals>.update_grad()
#     179 self._update_fun()
#     180 self.ngev += 1
# --> 181 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     182                            **finite_diff_options)
#
# File ~/miniconda3/envs/BIGFAM/lib/python3.9/site-packages/scipy/optimize/_numdiff.py:519, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     516     use_one_sided = False
#     518 if sparsity is None:
# --> 519     return _dense_difference(fun_wrapped, x0, f0, h,
#     520                              use_one_sided, method)
#     521 else:
#     522     if not issparse(sparsity) and len(sparsity) == 2:
#
# File ~/miniconda3/envs/BIGFAM/lib/python3.9/site-packages/scipy/optimize/_numdiff.py:590, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     588     x = x0 + h_vecs[i]
#     589     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 590     df = fun(x) - f0
#     591 elif method == '3-point' and use_one_sided[i]:
#     592     x1 = x0 + h_vecs[i]
#
# File ~/miniconda3/envs/BIGFAM/lib/python3.9/site-packages/scipy/optimize/_numdiff.py:470, in approx_derivative.<locals>.fun_wrapped(x)
#     467 if xp.isdtype(x.dtype, "real floating"):
#     468     x = xp.astype(x, x0.dtype)
# --> 470 f = np.atleast_1d(fun(x, *args, **kwargs))
#     471 if f.ndim > 1:
#     472     raise RuntimeError("`fun` return value has "
#     473                        "more than 1 dimension.")
#
# File ~/miniconda3/envs/BIGFAM/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# File /data/jerrylee/pjt/BIGFAM.v.0.1/BIGFAM/obj1.py:71, in _lossFunc(xs, df_lmbds_w0)
#      69 df_lmbds["slope"] = df_lmbds["slope"].astype(float)
#      70 df_lmbds["log_slope"] = np.log2(df_lmbds["slope"])
# ---> 71 df_lmbds["slope_pred"] = (1/2)**df_lmbds["DOR"] * G\
#      72                        + w0**(df_lmbds["DOR"] - 1) * S1
#      73 df_lmbds["log_slope_pred"] = np.log2(df_lmbds["slope_pred"])
#      74 df_lmbds["log_slope_pred"] = df_lmbds["log_slope_pred"].astype(float)
#
# File ~/miniconda3/envs/BIGFAM/lib/python3.9/site-packages/pandas/core/frame.py:3612, in DataFrame.__setitem__(self, key, value)
#    3609     self._setitem_array([key], value)
#    3610 else:
#    3611     # set column
# -> 3612     self._set_item(key, value)
#
# File ~/miniconda3/envs/BIGFAM/lib/python3.9/site-packages/pandas/core/frame.py:3797, in DataFrame._set_item(self, key, value)
#    3794         if isinstance(existing_piece, DataFrame):
#    3795             value = np.tile(value, (len(existing_piece.columns), 1)).T
# -> 3797 self._set_item_mgr(key, value)
#
# File ~/miniconda3/envs/BIGFAM/lib/python3.9/site-packages/pandas/core/frame.py:3762, in DataFrame._set_item_mgr(self, key, value)
#    3758 # check if we are modifying a copy
#    3759 # try to set first as we want an invalid
#    3760 # value exception to occur first
#    3761 if len(self):
# -> 3762     self._check_setitem_copy(stacklevel=5)
#
# File ~/miniconda3/envs/BIGFAM/lib/python3.9/site-packages/pandas/core/generic.py:3860, in NDFrame._check_setitem_copy(self, stacklevel, t, force)
#    3857         self._check_setitem_copy(stacklevel=4, t="referent")
#    3858     return False
# -> 3860 @final
#    3861 def _check_setitem_copy(self, stacklevel=4, t="setting", force=False):
#    3862     """
#    3863
#    3864     Parameters
#    (...)
#    3889
#    3890     """
#    3891     # return early if the check is not needed
#
# KeyboardInterrupt:

# %%
pheno_name
# Out:
# 'hips'
