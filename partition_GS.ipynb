# %%
import pandas as pd
from BIGFAM import obj1

# %% [markdown]
# # Step 1. Load FR-reg

# %%
df_frreg = pd.read_csv("./test-data/test.DOR.frreg", sep='\t')
df_frreg
# Out:
#    DOR   slope     se      n
# 0    1  0.3000  0.005  10000
# 1    2  0.1350  0.005  10000
# 2    3  0.0645  0.005  10000

# %% [markdown]
# # Step 2. BIGFAM

# %%
df_frlogreg, df_gsw = obj1.obj1(
    df_frreg,
    n_repeat_cv=5, # default 10
    n_block=5, # default 10
    )
# Out:
#           Slope Test Result : High (slope is 1.110(1.034, 1.207))
#
#
#           Predict Variance Components...
#
# 1..2..3..4..5..
#           Prediction Result :
#           - Vg : 0.499(0.420,0.521)
#           - Vs : 0.051(0.040,0.088)
#           - ws : 5.000(25.000,2.762)
